# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sb

# %%
df = pd.read_csv("bill_survey.csv")
df.head()
# Out:
#      City   Bill
# 0  Mumbai  15400
# 1  Mumbai   6700
# 2  Mumbai  16300
# 3  Mumbai   2100
# 4  Mumbai   4600

# %%
df.City.nunique()
# Out:
# 207

# %%
df.shape
# Out:
# (10350, 2)

# %%
sb.histplot(df[df.City=="Mumbai"].Bill,kde=True)
plt.show()

# %%
sns.histplot(df[df.City=="Surat"].Bill, kde=True)
plt.show()

# %%
g=df.groupby("City")

simple_means=[]
for key,value in g:
    simple_means.append(value.Bill.mean())
simple_means[:5]
# Out:
# [6276.0, 6084.0, 5990.0, 5588.0, 5680.0]

# %%
sb.histplot(simple_means,kde=True)
plt.show()
